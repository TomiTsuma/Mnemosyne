# %%
import pandas as pd
import sys
sys.path.append("../")
sys.path.append("../scripts")

# %%
from pathlib import Path

# %%
import json

# %%
from _mnemo_client import (
    Client,
    ServerProc,
    TestRunner,
    GREEN,
    RED,
    YELLOW,
    RESET,
)

# %%
client = Client("http://localhost:1143")

# %%
REPO_ROOT = Path("/tmp/mnemosyne")
DB = "su_test_db"
LOCAL_UNIT = "su_local"
S3_UNIT = "su_s3"
TABLE = "su_file"
tmp = "/tmp/mnemosyne"

# %%
json.loads(client.query(f"CREATE DATABASE IF NOT EXISTS {DB}").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 2.04,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"USE DATABASE {DB}").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 7.61,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
import tempfile
with tempfile.TemporaryDirectory(prefix="mnemo_su_") as tmp:
    print(tmp)
# Out:
# C:\Users\TSUMA~1.THO\AppData\Local\Temp\mnemo_su_rle34e7c

# %%
json.loads(client.query("SHOW DATABASES").body)
# Out:
# {'rows': 4,
#  'columns': ['databases'],
#  'data': [['{'], ['sales_db'], ['sales_db2'], ['su_test_db']],
#  'duration_ms': 0.23,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"DROP STORAGE_UNIT {LOCAL_UNIT}").body)
# Out:
# {'error': 'Exception: Storage unit is in use: su_local', 'status_code': 500}

# %%
json.loads(client.query(f"CREATE STORAGE_UNIT {LOCAL_UNIT} TYPE LOCAL PATH '{tmp}'").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 3.82,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"DESCRIBE STORAGE_UNIT {LOCAL_UNIT}").body)
# Out:
# {'rows': 12,
#  'columns': ['field', 'value'],
#  'data': [['name', 'su_local'],
#   ['type', 'LOCAL'],
#   ['status', 'ONLINE'],
#   ['path', '/tmp/mnemosyne'],
#   ['endpoint', ''],
#   ['bucket', ''],
#   ['region', ''],
#   ['capacity_bytes', '1023117619200'],
#   ['used_bytes', '966165065728'],
#   ['available_bytes', '56952553472'],
#   ['reference_count', '0'],
#   ['capabilities', 'BLOCK_STORAGE']],
#  'duration_ms': 0.42,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"SHOW STORAGE_UNITS WHERE type NOT 'LOCAL'").body)
# Out:
# {'rows': 1,
#  'columns': ['name', 'type', 'status'],
#  'data': [['su_local', 'LOCAL', 'ONLINE']],
#  'duration_ms': 0.18,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"CREATE TABLE {TABLE} (id Float64, val Float64) Engine=File STORAGE_UNIT {LOCAL_UNIT} ").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 3.39,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
# json.loads(client.query(f"INSERT INTO {TABLE} VALUES (1.0, 10.5), (2.0, 20.5), (3.0, 30.5)").body)
json.loads(client.query(f"INSERT INTO {TABLE} VALUES (15.0, 10.5), (12.0, 21.5), (33.0, 310.53)").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 12.62,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"SELECT * FROM {TABLE}").body)
# Out:
# {'rows': 3,
#  'columns': ['id', 'val'],
#  'data': [[15, 10], [12, 21], [33, 310]],
#  'duration_ms': 1.46,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"SHOW STORAGE_USAGE").body)
# Out:
# {'rows': 1,
#  'columns': ['name',
#   'total_bytes',
#   'used_bytes',
#   'available_bytes',
#   'used_pct'],
#  'data': [['su_local',
#    '1023117619200',
#    '966166814720',
#    '56950804480',
#    '94.433601']],
#  'duration_ms': 8.75,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
# Out:
# {'rows': 1,
#  'columns': ['name', 'type', 'status'],
#  'data': [['su_local', 'LOCAL', 'ONLINE']],
#  'duration_ms': 0.06,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"CREATE STORAGE_UNIT {S3_UNIT} TYPE S3 BUCKET 'mnemo' ENDPOINT 'http://100.127.65.29:9000' ACCESS_KEY 'admin' SECRET_KEY 'password'").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 5.56,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"DESCRIBE STORAGE_UNIT {S3_UNIT}").body)
# Out:
# {'rows': 12,
#  'columns': ['field', 'value'],
#  'data': [['name', 'su_s3'],
#   ['type', 'S3'],
#   ['status', 'ONLINE'],
#   ['path', ''],
#   ['endpoint', 'http://100.127.65.29:9000'],
#   ['bucket', 'mnemo'],
#   ['region', ''],
#   ['capacity_bytes', '0'],
#   ['used_bytes', '0'],
#   ['available_bytes', '0'],
#   ['reference_count', '0'],
#   ['capabilities', 'OBJECT_STORAGE']],
#  'duration_ms': 0.74,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query(f"CREATE TABLE s3_tbl (id Float64, val Float64) Engine=File STORAGE_UNIT {S3_UNIT} ").body)
# Out:
# {'error': 'Exception: S3 storage units do not support File engine I/O yet',
#  'status_code': 500}
