# %%
import pandas as pd
import sys
sys.path.append("../")
sys.path.append("../scripts")

# %%
import json

# %%
from _mnemo_client import (
    Client,
    ServerProc,
    TestRunner,
    GREEN,
    RED,
    YELLOW,
    RESET,
)

# %%
client = Client("http://localhost:1143")

# %%
res = client.query("CREATE DATABASE IF NOT EXISTS sales_db2")

# %%
json.loads(res.body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 0.27,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SHOW DATABASES").body)
# Out:
# {'rows': 2,
#  'columns': ['databases'],
#  'data': [['sales_db'], ['sales_db2']],
#  'duration_ms': 0.15,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("USE DATABASE sales_db").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 0.16,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("CREATE TABLE IF NOT EXISTS customers2 (customer_id Int64, name String, age Int64)").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 0.22,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SHOW TABLES").body)
# Out:
# {'rows': 1,
#  'columns': ['name'],
#  'data': [['customers']],
#  'duration_ms': 0.17,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("DESCRIBE customers").body)
# Out:
# {'rows': 3,
#  'columns': ['name', 'type'],
#  'data': [['customer_id', 'Int64'], ['name', 'String'], ['age', 'Int64']],
#  'duration_ms': 21.54,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("INSERT INTO customers VALUES (4, 'Diana', 28)").body)
json.loads(client.query("INSERT INTO customers VALUES (5, 'Marlon', 22)").body)
json.loads(client.query("INSERT INTO customers VALUES (6, 'Sean', 27)").body)
json.loads(client.query("INSERT INTO customers VALUES (7, 'Alexis', 28)").body)
json.loads(client.query("INSERT INTO customers VALUES (8, 'Alicia', 21)").body)
json.loads(client.query("INSERT INTO customers VALUES (9, 'Maya', 35)").body)
json.loads(client.query("INSERT INTO customers VALUES (10, 'Karla', 23)").body)
json.loads(client.query("INSERT INTO customers VALUES (11, 'Wayne', 11)").body)
# Out:
# {'rows': 1,
#  'columns': ['result'],
#  'data': [['OK']],
#  'duration_ms': 0.08,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers").body)
# Out:
# {'rows': 9,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[4, 'Diana', 28],
#   [4, 'Diana', 28],
#   [5, 'Marlon', 22],
#   [6, 'Sean', 27],
#   [7, 'Alexis', 28],
#   [8, 'Alicia', 21],
#   [9, 'Maya', 35],
#   [10, 'Karla', 23],
#   [11, 'Wayne', 11]],
#  'duration_ms': 1.81,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT name FROM customers").body)
# Out:
# {'rows': 9,
#  'columns': ['name'],
#  'data': [['Diana'],
#   ['Diana'],
#   ['Marlon'],
#   ['Sean'],
#   ['Alexis'],
#   ['Alicia'],
#   ['Maya'],
#   ['Karla'],
#   ['Wayne']],
#  'duration_ms': 0.18,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT name,age FROM customers").body)
# Out:
# {'rows': 9,
#  'columns': ['name', 'age'],
#  'data': [['Diana', 28],
#   ['Diana', 28],
#   ['Marlon', 22],
#   ['Sean', 27],
#   ['Alexis', 28],
#   ['Alicia', 21],
#   ['Maya', 35],
#   ['Karla', 23],
#   ['Wayne', 11]],
#  'duration_ms': 0.25,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT name ,age FROM customers WHERE age >27").body)
# Out:
# {'rows': 4,
#  'columns': ['name', 'age'],
#  'data': [['Diana', 28], ['Diana', 28], ['Alexis', 28], ['Maya', 35]],
#  'duration_ms': 0.36,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers WHERE customer_id = 4").body)
# Out:
# {'rows': 2,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[4, 'Diana', 28], [4, 'Diana', 28]],
#  'duration_ms': 0.26,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers WHERE (age > 27 AND age < 40) OR customer_id = 8").body)
# Out:
# {'rows': 5,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[4, 'Diana', 28],
#   [4, 'Diana', 28],
#   [7, 'Alexis', 28],
#   [8, 'Alicia', 21],
#   [9, 'Maya', 35]],
#  'duration_ms': 0.25,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers ORDER BY age").body)
# Out:
# {'rows': 9,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[11, 'Wayne', 11],
#   [8, 'Alicia', 21],
#   [5, 'Marlon', 22],
#   [10, 'Karla', 23],
#   [6, 'Sean', 27],
#   [4, 'Diana', 28],
#   [4, 'Diana', 28],
#   [7, 'Alexis', 28],
#   [9, 'Maya', 35]],
#  'duration_ms': 2.31,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers ORDER BY age DESC").body)
# Out:
# {'rows': 9,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[9, 'Maya', 35],
#   [4, 'Diana', 28],
#   [4, 'Diana', 28],
#   [7, 'Alexis', 28],
#   [6, 'Sean', 27],
#   [10, 'Karla', 23],
#   [5, 'Marlon', 22],
#   [8, 'Alicia', 21],
#   [11, 'Wayne', 11]],
#  'duration_ms': 0.29,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT COUNT(name) as total_customers FROM customers").body)
# Out:
# {'rows': 1,
#  'columns': ['COUNT(name)'],
#  'data': [[9]],
#  'duration_ms': 0.16,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT AVG(age) as average_customer_age FROM customers").body)
# Out:
# {'rows': 1,
#  'columns': ['AVG(age)'],
#  'data': [[24]],
#  'duration_ms': 0.3,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT AVG(age) as average_customer_age FROM customers WHERE age > 22").body)
# Out:
# {'rows': 1,
#  'columns': ['AVG(age)'],
#  'data': [[28]],
#  'duration_ms': 0.28,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT MIN(age) as minimum_customer_age FROM customers").body)
# Out:
# {'rows': 1,
#  'columns': ['MIN(age)'],
#  'data': [[11]],
#  'duration_ms': 0.22,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT MAX(age) as maximum_customer_age FROM customers").body)
# Out:
# {'rows': 1,
#  'columns': ['MAX(age)'],
#  'data': [[35]],
#  'duration_ms': 0.28,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT age, COUNT(*) FROM customers GROUP BY age").body)
# Out:
# {'rows': 7,
#  'columns': ['age', 'COUNT(*)'],
#  'data': [[11, 1], [21, 1], [22, 1], [23, 1], [27, 1], [28, 3], [35, 1]],
#  'duration_ms': 0.23,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT age, COUNT(*) FROM customers GROUP BY age HAVING COUNT(*) > 1").body)
# Out:
# {'rows': 1,
#  'columns': ['age', 'COUNT(*)'],
#  'data': [[28, 3]],
#  'duration_ms': 0.23,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers WHERE age < (SELECT AVG(age) FROM customers)").body)
# Out:
# {'rows': 4,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[5, 'Marlon', 22],
#   [8, 'Alicia', 21],
#   [10, 'Karla', 23],
#   [11, 'Wayne', 11]],
#  'duration_ms': 0.46,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT * FROM customers WHERE customer_id IN (SELECT customer_id FROM customers WHERE age > 30)").body)
# Out:
# {'rows': 1,
#  'columns': ['customer_id', 'name', 'age'],
#  'data': [[9, 'Maya', 35]],
#  'duration_ms': 0.45,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT customer_id, age FROM customers LIMIT 3").body)
# Out:
# {'rows': 9,
#  'columns': ['customer_id', 'age'],
#  'data': [[4, 28],
#   [4, 28],
#   [5, 22],
#   [6, 27],
#   [7, 28],
#   [8, 21],
#   [9, 35],
#   [10, 23],
#   [11, 11]],
#  'duration_ms': 0.19,
#  'bytes_read': 0,
#  'bytes_written': 0}

# %%
json.loads(client.query("SELECT customer_id, age, COUNT(age) OVER (PARTITION BY age ORDER BY customer_id) FROM customers").body)
# Out:
# {'rows': 9,
#  'columns': ['customer_id', 'age', 'COUNT(age)_over'],
#  'data': [[4, 28, 3],
#   [4, 28, 3],
#   [5, 22, 1],
#   [6, 27, 1],
#   [7, 28, 3],
#   [8, 21, 1],
#   [9, 35, 1],
#   [10, 23, 1],
#   [11, 11, 1]],
#  'duration_ms': 0.33,
#  'bytes_read': 0,
#  'bytes_written': 0}
